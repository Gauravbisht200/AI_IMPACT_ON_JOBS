# %% [markdown]
# # IMPACT OF AI ON JOBS
# In today's rapidly evolving business landscape, the integration of Artificial Intelligence (AI) is becoming increasingly crucial for optimizing operations, enhancing efficiency, and improving decision-making across various domains. As part of this project, my task is to analyze a dataset containing information about different job roles within a company and derive meaningful insights to identify potential candidates for AI-driven automation.

# %% [markdown]
# ### IMPORTING LIBRARIES AND VIEWING DATA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("ai job replace.csv")
pd.set_option('display.max_rows', 10)
df
# Out:
#                  Job titiles AI Impact  Tasks  AI models  AI_Workload_Ratio  \
# 0     Communications Manager       98%    365       2546           0.143362
# 1             Data Collector       95%    299       2148           0.139199
# 2                 Data Entry       95%    325       2278           0.142669
# 3                 Mail Clerk       95%    193       1366           0.141288
# 4         Compliance Officer       92%    194       1369           0.141709
# ...                      ...       ...    ...        ...                ...
# 4701                  Singer        5%    686       2798           0.245175
# 4702                 Airport        5%    556       2206           0.252040
# 4703                Director        5%   1316       4695           0.280298
# 4704                   Nurse        5%    710       2594           0.273709
# 4705              Technician        5%    825       3256           0.253378
#
#                          Domain
# ...

# %% [markdown]
# ### DOMAINS PRESENT IN DATA

# %%
distinct_domain=df['Domain'].unique()
for Domain in distinct_domain:
    print(Domain)
# Out:
# Communication & PR
# Data & IT
# Administrative & Clerical
# Leadership & Strategy
# Medical & Healthcare
# Supply Chain & Logistics
# Law Enforcement
# Construction
# Sales & Marketing
# Hospitality

# %%
pd.set_option('display.expand_frame_repr', False) 
pd.set_option('display.max_rows', 10)
df
# Out:
#                  Job titiles AI Impact  Tasks  AI models  AI_Workload_Ratio                     Domain
# 0     Communications Manager       98%    365       2546           0.143362         Communication & PR
# 1             Data Collector       95%    299       2148           0.139199                  Data & IT
# 2                 Data Entry       95%    325       2278           0.142669  Administrative & Clerical
# 3                 Mail Clerk       95%    193       1366           0.141288      Leadership & Strategy
# 4         Compliance Officer       92%    194       1369           0.141709       Medical & Healthcare
# ...                      ...       ...    ...        ...                ...                        ...
# 4701                  Singer        5%    686       2798           0.245175                  Data & IT
# 4702                 Airport        5%    556       2206           0.252040  Administrative & Clerical
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4706 entries, 0 to 4705
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job titiles        4706 non-null   object
#  1   AI Impact          4706 non-null   object
#  2   Tasks              4706 non-null   int64
#  3   AI models          4706 non-null   int64
#  4   AI_Workload_Ratio  4706 non-null   float64
#  5   Domain             4706 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 220.7+ KB

# %% [markdown]
# # CLEANING THE DATA

# %%
df['AI Impact'] = df['AI Impact'].str.replace('%', '',).astype(int)
pd.set_option('display.max_rows', 10)
df
# Out:
#                  Job titiles  AI Impact  Tasks  AI models  AI_Workload_Ratio                     Domain
# 0     Communications Manager         98    365       2546           0.143362         Communication & PR
# 1             Data Collector         95    299       2148           0.139199                  Data & IT
# 2                 Data Entry         95    325       2278           0.142669  Administrative & Clerical
# 3                 Mail Clerk         95    193       1366           0.141288      Leadership & Strategy
# 4         Compliance Officer         92    194       1369           0.141709       Medical & Healthcare
# ...                      ...        ...    ...        ...                ...                        ...
# 4701                  Singer          5    686       2798           0.245175                  Data & IT
# 4702                 Airport          5    556       2206           0.252040  Administrative & Clerical
# ...

# %%
df.shape
# Out:
# (4706, 6)

# %%
a=df.drop_duplicates()

# %% [markdown]
# #### DOING SOME EXPLORATORY ANALYSIS ON THE CLEANED DATA

# %%
plt.hist(df['AI Impact'], bins=range(0, 110, 5), edgecolor='black', alpha=0.7)
plt.xlabel('AI Impact in percent')
plt.ylabel('Number of Jobs affected')
plt.title('Distribution of AI Impact for diffrent Jobs')
# Out:
# Text(0.5, 1.0, 'Distribution of AI Impact for diffrent Jobs')

# %% [markdown]
# #### GROUPING OF DATA WITH RESPECT TO DOMAIN AND GETTING MEAN DATA OF EACH DOMAIN FOR BETTER UNDERSTANDING

# %%
grouped_data=df.groupby(['Domain'])
print(grouped_data.mean())
# Out:
#                            AI Impact       Tasks    AI models  AI_Workload_Ratio
# Domain
# Administrative & Clerical  30.339703  395.673036  1808.208068                NaN
# Communication & PR         30.388535  398.898089  1836.957537           0.200423
# Construction               30.293617  410.734043  1849.408511                NaN
# Data & IT                  30.354565  392.452229  1814.462845                NaN
# Hospitality                30.265957  416.682979  1869.451064           0.204731
# Law Enforcement            30.308511  401.202128  1778.427660                NaN
# Leadership & Strategy      30.324841  398.779193  1817.467091           0.204877
# Medical & Healthcare       30.295117  386.643312  1760.847134                NaN
# Sales & Marketing          30.280851  412.740426  1855.704255           0.207530
# Supply Chain & Logistics   30.273885  393.356688  1786.021231                NaN
# ...

# %%
grouped_data.describe()
# Out:
#                           AI Impact                                                     Tasks              ... AI models         AI_Workload_Ratio
#                               count       mean        std  min   25%   50%   75%   max  count        mean  ...       75%     max             count      mean       std       min       25%       50%       75%       max
# Domain                                                                                                     ...
# Administrative & Clerical     471.0  30.339703  18.272037  5.0  15.0  25.0  40.0  95.0  471.0  395.673036  ...   2292.00  5304.0             471.0       inf       NaN  0.052980  0.137821  0.192308  0.260016       inf
# Communication & PR            471.0  30.388535  18.339232  5.0  15.0  25.0  40.0  98.0  471.0  398.898089  ...   2318.00  5328.0             471.0  0.200423  0.075258  0.065217  0.134108  0.173410  0.258967  0.401211
# ...

# %% [markdown]
# ### INTRODUCING A VARIABLE COMMULATIVE_AI_AUTOMATION
# project's core challenge arises from the presence of two critical columns in the dataset: "AI Impact" and "AI Workload." These two columns presented a significant dilemma due to the lack of a discernible deciding factor that would facilitate prioritization.so we Introduce a new column COMMULATIVE_AI_AUTOMATION -now the more the value of COMMULATIVE_AI_AUTOMATION the more it is benificial for the company to Integrate AI with that particular job.

# %% [markdown]
# ## DATA OF Communication & PR DOMAIN

# %%
CP=grouped_data.get_group('Communication & PR')
pd.set_option('display.max_rows', 10)
CP['COMMULATIVE_AI_AUTOMATION']=CP['AI Impact'] * CP['AI_Workload_Ratio']
columns_to_print =['Job titiles','AI Impact','AI_Workload_Ratio','COMMULATIVE_AI_AUTOMATION']
CP[columns_to_print].sort_values(by='COMMULATIVE_AI_AUTOMATION')
# Out:
# C:\Users\91965\AppData\Local\Temp\ipykernel_8172\3619635277.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CP['COMMULATIVE_AI_AUTOMATION']=CP['AI Impact'] * CP['AI_Workload_Ratio']
#                               Job titiles  AI Impact  AI_Workload_Ratio  COMMULATIVE_AI_AUTOMATION
# 4540                    Animal Technician          5           0.189715                   0.948575
# 4480                     School Secretary          5           0.204117                   1.020583
# 4660                        Photo Stylist          5           0.206203                   1.031014
# 4590                         School Nurse          5           0.213949                   1.069746
# ...

# %% [markdown]
# ## DATA OF Data & IT DOMAIN

# %%
DI=grouped_data.get_group('Data & IT')
pd.set_option('display.max_rows', 10)
DI['COMMULATIVE_AI_AUTOMATION']=DI['AI Impact'] * DI['AI_Workload_Ratio']
columns_to_print =['Job titiles','AI Impact','AI_Workload_Ratio','COMMULATIVE_AI_AUTOMATION']
CP[columns_to_print].sort_values(by='COMMULATIVE_AI_AUTOMATION')
# Out:
# C:\Users\91965\AppData\Local\Temp\ipykernel_8172\3815217732.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DI['COMMULATIVE_AI_AUTOMATION']=DI['AI Impact'] * DI['AI_Workload_Ratio']
#                               Job titiles  AI Impact  AI_Workload_Ratio  COMMULATIVE_AI_AUTOMATION
# 4540                    Animal Technician          5           0.189715                   0.948575
# 4480                     School Secretary          5           0.204117                   1.020583
# 4660                        Photo Stylist          5           0.206203                   1.031014
# 4590                         School Nurse          5           0.213949                   1.069746
# ...

# %% [markdown]
# ## DATA OF Administrative & Clerical DOMAIN

# %%
AC=grouped_data.get_group('Administrative & Clerical')
pd.set_option('display.max_rows', 10)
AC['COMMULATIVE_AI_AUTOMATION']=AC['AI Impact'] * AC['AI_Workload_Ratio']
columns_to_print =['Job titiles','AI Impact','AI_Workload_Ratio','COMMULATIVE_AI_AUTOMATION']
CP[columns_to_print].sort_values(by='COMMULATIVE_AI_AUTOMATION')
# Out:
# C:\Users\91965\AppData\Local\Temp\ipykernel_8172\2460565324.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AC['COMMULATIVE_AI_AUTOMATION']=AC['AI Impact'] * AC['AI_Workload_Ratio']
#                               Job titiles  AI Impact  AI_Workload_Ratio  COMMULATIVE_AI_AUTOMATION
# 4540                    Animal Technician          5           0.189715                   0.948575
# 4480                     School Secretary          5           0.204117                   1.020583
# 4660                        Photo Stylist          5           0.206203                   1.031014
# 4590                         School Nurse          5           0.213949                   1.069746
# ...

# %% [markdown]
# ## DATA OF Leadership & Strategy DOMAIN

# %%
LS=grouped_data.get_group('Leadership & Strategy')
pd.set_option('display.max_rows', 10)
LS['COMMULATIVE_AI_AUTOMATION']=LS['AI Impact'] * LS['AI_Workload_Ratio']
columns_to_print =['Job titiles','AI Impact','AI_Workload_Ratio','COMMULATIVE_AI_AUTOMATION']
LS[columns_to_print].sort_values(by='COMMULATIVE_AI_AUTOMATION')
# Out:
# C:\Users\91965\AppData\Local\Temp\ipykernel_8172\133156576.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LS['COMMULATIVE_AI_AUTOMATION']=LS['AI Impact'] * LS['AI_Workload_Ratio']
#                        Job titiles  AI Impact  AI_Workload_Ratio  COMMULATIVE_AI_AUTOMATION
# 4503                      Sculptor          5           0.188259                   0.941296
# 4623         Physical Therapy Aide          5           0.207731                   1.038656
# 4663                       Stylist          5           0.210246                   1.051230
# 4553                      Minister          5           0.214802                   1.074011
# ...

# %% [markdown]
# ## DATA OF Medical & Healthcare DOMAIN

# %%
MH=grouped_data.get_group('Medical & Healthcare')
pd.set_option('display.max_rows', 10)
MH['COMMULATIVE_AI_AUTOMATION']=MH['AI Impact'] * MH['AI_Workload_Ratio']
columns_to_print =['Job titiles','AI Impact','AI_Workload_Ratio','COMMULATIVE_AI_AUTOMATION']
MH[columns_to_print].sort_values(by='COMMULATIVE_AI_AUTOMATION')
# Out:
# C:\Users\91965\AppData\Local\Temp\ipykernel_8172\1614402806.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   MH['COMMULATIVE_AI_AUTOMATION']=MH['AI Impact'] * MH['AI_Workload_Ratio']
#                            Job titiles  AI Impact  AI_Workload_Ratio  COMMULATIVE_AI_AUTOMATION
# 4594                Resident Assistant          5           0.193208                   0.966038
# 4554                            Pastor          5           0.206960                   1.034799
# 4504                     Tattoo Artist          5           0.210584                   1.052922
# 4624        Physical Therapy Assistant          5           0.210618                   1.053088
# ...

# %% [markdown]
# ## DATA OF Supply Chain & Logistics DOMAIN

# %%
SCL=grouped_data.get_group('Supply Chain & Logistics')
pd.set_option('display.max_rows', 10)
SCL['COMMULATIVE_AI_AUTOMATION']=SCL['AI Impact'] * SCL['AI_Workload_Ratio']
columns_to_print =['Job titiles','AI Impact','AI_Workload_Ratio','COMMULATIVE_AI_AUTOMATION']
SCL[columns_to_print].sort_values(by='COMMULATIVE_AI_AUTOMATION')
# Out:
# C:\Users\91965\AppData\Local\Temp\ipykernel_8172\141975611.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SCL['COMMULATIVE_AI_AUTOMATION']=SCL['AI Impact'] * SCL['AI_Workload_Ratio']
#                        Job titiles  AI Impact  AI_Workload_Ratio  COMMULATIVE_AI_AUTOMATION
# 4475                        Reader          5           0.199174                   0.995870
# 4625   Physical Therapy Technician          5           0.203057                   1.015284
# 4555                        Priest          5           0.210606                   1.053030
# 4665                     Herbalist          5           0.214539                   1.072695
# ...

# %% [markdown]
# ## DATA OF Law Enforcement DOMAIN

# %%
LE=grouped_data.get_group('Law Enforcement')
pd.set_option('display.max_rows', 10)
LE['COMMULATIVE_AI_AUTOMATION']=LE['AI Impact'] * LE['AI_Workload_Ratio']
columns_to_print =['Job titiles','AI Impact','AI_Workload_Ratio','COMMULATIVE_AI_AUTOMATION']
LE[columns_to_print].sort_values(by='COMMULATIVE_AI_AUTOMATION')
# Out:
# C:\Users\91965\AppData\Local\Temp\ipykernel_8172\3529361991.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   LE['COMMULATIVE_AI_AUTOMATION']=LE['AI Impact'] * LE['AI_Workload_Ratio']
#                    Job titiles  AI Impact  AI_Workload_Ratio  COMMULATIVE_AI_AUTOMATION
# 4616             State Trooper          5           0.179658                   0.898292
# 4626       Rehabilitation Aide          5           0.197471                   0.987356
# 4556                     Rabbi          5           0.208689                   1.043446
# 4586        Occupational Nurse          5           0.209369                   1.046845
# 4496             Choreographer          5           0.218551                   1.092757
# ...

# %% [markdown]
# ## DATA OF Construction DOMAIN

# %%
C=grouped_data.get_group('Construction')
pd.set_option('display.max_rows', 10)
C['COMMULATIVE_AI_AUTOMATION']=C['AI Impact'] * C['AI_Workload_Ratio']
columns_to_print =['Job titiles','AI Impact','AI_Workload_Ratio','COMMULATIVE_AI_AUTOMATION']
C[columns_to_print].sort_values(by='COMMULATIVE_AI_AUTOMATION')
# Out:
# C:\Users\91965\AppData\Local\Temp\ipykernel_8172\2566602950.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   C['COMMULATIVE_AI_AUTOMATION']=C['AI Impact'] * C['AI_Workload_Ratio']
#                     Job titiles  AI Impact  AI_Workload_Ratio  COMMULATIVE_AI_AUTOMATION
# 4627  Rehabilitation Technician          5           0.198885                   0.994424
# 4537     Animal Care Technician          5           0.200964                   1.004818
# 4497                  Craftsman          5           0.204531                   1.022653
# 4587       Operating Room Nurse          5           0.208313                   1.041566
# 4637           Apparel Designer          5           0.218708                   1.093542
# ...

# %% [markdown]
# ## DATA OF Sales & Marketing DOMAIN

# %%
SM=grouped_data.get_group('Sales & Marketing')
pd.set_option('display.max_rows', 10)
SM['COMMULATIVE_AI_AUTOMATION']=SM['AI Impact'] * SM['AI_Workload_Ratio']
columns_to_print =['Job titiles','AI Impact','AI_Workload_Ratio','COMMULATIVE_AI_AUTOMATION']
SM[columns_to_print].sort_values(by='COMMULATIVE_AI_AUTOMATION')
# Out:
# C:\Users\91965\AppData\Local\Temp\ipykernel_8172\629732739.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SM['COMMULATIVE_AI_AUTOMATION']=SM['AI Impact'] * SM['AI_Workload_Ratio']
#                     Job titiles  AI Impact  AI_Workload_Ratio  COMMULATIVE_AI_AUTOMATION
# 4538           Animal Caretaker          5           0.191673                   0.958363
# 4568                  Ombudsman          5           0.214706                   1.073529
# 4478           Religion Teacher          5           0.225031                   1.125156
# 4468          Preschool Teacher          5           0.230484                   1.152422
# 4588       Rehabilitation Nurse          5           0.231043                   1.155216
# ...

# %% [markdown]
# ## DATA OF Hospitality DOMAIN

# %%
H=grouped_data.get_group('Hospitality')
pd.set_option('display.max_rows', 10)
H['COMMULATIVE_AI_AUTOMATION']=H['AI Impact'] * H['AI_Workload_Ratio']
columns_to_print =['Job titiles','AI Impact','AI_Workload_Ratio','COMMULATIVE_AI_AUTOMATION']
H[columns_to_print].sort_values(by='COMMULATIVE_AI_AUTOMATION')
# Out:
# C:\Users\91965\AppData\Local\Temp\ipykernel_8172\1988552384.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   H['COMMULATIVE_AI_AUTOMATION']=H['AI Impact'] * H['AI_Workload_Ratio']
#                  Job titiles  AI Impact  AI_Workload_Ratio  COMMULATIVE_AI_AUTOMATION
# 4539           Animal Keeper          5           0.193732                   0.968661
# 4659        Personal Stylist          5           0.212096                   1.060481
# 4609   Forensic Psychologist          5           0.221381                   1.106906
# 4469         Primary Teacher          5           0.222156                   1.110778
# 4639          Beauty Advisor          5           0.224257                   1.121284
# ...
